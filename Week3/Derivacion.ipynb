# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc

# %%
epsilon = 1

while 1 + epsilon != 1:
    epsilon *= 0.5

print(epsilon)
# Out:
# 1.1102230246251565e-16

# %%
def epsilon(x):
    return np.sin(x) - (x -x**3/6)

x = 3*np.pi/2
print(epsilon(x)/epsilon(x/2))
# Out:
# 22.086127060303767

# %%
def function(x):
    return np.sin(x)
def functderivative(x):
    return np.cos(x)

# %%
x = np.linspace(0, 2*np.pi,50)
x
# Out:
# array([0.        , 0.12822827, 0.25645654, 0.38468481, 0.51291309,
#        0.64114136, 0.76936963, 0.8975979 , 1.02582617, 1.15405444,
#        1.28228272, 1.41051099, 1.53873926, 1.66696753, 1.7951958 ,
#        1.92342407, 2.05165235, 2.17988062, 2.30810889, 2.43633716,
#        2.56456543, 2.6927937 , 2.82102197, 2.94925025, 3.07747852,
#        3.20570679, 3.33393506, 3.46216333, 3.5903916 , 3.71861988,
#        3.84684815, 3.97507642, 4.10330469, 4.23153296, 4.35976123,
#        4.48798951, 4.61621778, 4.74444605, 4.87267432, 5.00090259,
#        5.12913086, 5.25735913, 5.38558741, 5.51381568, 5.64204395,
#        5.77027222, 5.89850049, 6.02672876, 6.15495704, 6.28318531])

# %%
plt.scatter(x,function(x))

# %%
def Derivative(f,x,h):
    d = (f(x+h)-f(x))/h
    return d

h = x[0] - x[1]
dev = Derivative(function,x,h)
    
plt.scatter(x,functderivative(x))
plt.scatter(x,dev)

# %%
plt.scatter(x,function(x)/dev)

# %%
def dev_backwards(f,x,h):
    d = (f(x)-f(x-h))/h
    return d

plt.scatter(x,dev_backwards(function,x,h))
plt.scatter(x,dev)

# %%
def dev_centrar(f,x,h):
    sub = Derivative(f,x,h)
    sob = dev_backwards(f,x,h)
    res = (sub - sob)/(2*h)
    return res

plt.scatter(x,dev_centrar(function,x,h))
plt.scatter(x,dev)
